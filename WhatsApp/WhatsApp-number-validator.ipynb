# %%
import requests
from bs4 import BeautifulSoup

# %%
goodpage = requests.get("https://api.whatsapp.com/send?phone=17073265665&text=test")
goodsoup = BeautifulSoup(goodpage.content, 'html.parser')

# %%
badpage = requests.get("https://api.whatsapp.com/send?phone=12127588797&text=test")
badsoup = BeautifulSoup(badpage.content, 'html.parser')

# %%
goodsoup
# Out:
# <!DOCTYPE html>
#
# <html class="no_js" id="facebook" lang="en">
# ...
